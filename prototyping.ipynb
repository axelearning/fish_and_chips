# %% [markdown]
# # Fish Classifier 🐠
# an application able to classify the fish of the Reunion Island’s lagoon

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
_MODEL_URL
# Out:
# 'https://drive.google.com/uc?export=download&id=1zv-S4dHsA84oEAyr1-2eGqLEvUANePD7'

# %%
# import model from drive
import urllib.request

MODEL_ID = '1zv-S4dHsA84oEAyr1-2eGqLEvUANePD7'
_MODEL_URL = f'https://drive.google.com/uc?export=download&id={MODEL_ID}'
urllib.request.urlretrieve(_MODEL_URL, "model.pkl")

model = load_learner("model.pkl")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /var/folders/tc/b8gn76gx5cxd9324lz63tg940000gn/T/ipykernel_11741/1973180035.py in <module>
#       6 urllib.request.urlretrieve(_MODEL_URL, "model.pkl")
#       7
# ----> 8 model = load_learner("model.pkl")
#
# /usr/local/lib/python3.9/site-packages/fastai/learner.py in load_learner(fname, cpu, pickle_module)
#     382     "Load a `Learner` object in `fname`, optionally putting it on the `cpu`"
#     383     distrib_barrier()
# --> 384     res = torch.load(fname, map_location='cpu' if cpu else None, pickle_module=pickle_module)
#     385     if hasattr(res, 'to_fp32'): res = res.to_fp32()
#     386     if cpu: res.dls.cpu()
#
# /usr/local/lib/python3.9/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     606                     return torch.jit.load(opened_file)
#     607                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
# --> 608         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     609
#     610
#
# /usr/local/lib/python3.9/site-packages/torch/serialization.py in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     775             "functionality.")
#     776
# --> 777     magic_number = pickle_module.load(f, **pickle_load_args)
#     778     if magic_number != MAGIC_NUMBER:
#     779         raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: invalid load key, '\x0a'.

# %%
# INPUTS
uploader = widgets.FileUpload() # multiple = true
vignette = widgets.Output() 
prediction = widgets.HTML()
btn_run = widgets.Button(description='Classify')
detailed_info = [widgets.HTML() for i in range(3)]


def show_img(img):
    vignette.clear_output()
    with vignette: 
        display(img.to_thumb(500,500))

def get_probs(model, img):
    _,_,probs = model.predict(img)
    return probs
    
def keep_k_top_classes(probs, k):
    probs, idx = probs.topk(k)
    preds = model.dls.vocab[idx]
    return probs, preds


def classify(change):
    if uploader.data:
        img = PILImage.create(uploader.data[-1])
        probs = get_probs(model, img)
        probs, preds = keep_k_top_classes(probs, k=3)

        prediction.value = f'<h1>{preds[0]}</h1>'
        show_img(img)
        for label, prob, pred in zip(detailed_info, probs, preds):
            label.value = f'{prob*100:.0f}% {pred}'
    else:
        prediction.value = "Upload a file first !"



btn_run.on_click(classify)

# Show
VBox([uploader, btn_run, prediction, vignette] + detailed_info)
